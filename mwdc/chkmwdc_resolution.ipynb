# %% [markdown]
# # Check MWDC position resolutions
# Input parquet file should be the output of `mwdc_processor.py` output without --output-wire-data option. <br>
# All the shifts parameters needs to be adjusted before checking this notebook.

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

#spark = SparkSession.builder.getOrCreate()
spark = SparkSession.builder.master("local[10]").getOrCreate()
spark.sparkContext.setLogLevel("ERROR")

df = spark.read.parquet("/home/h487/data/parquet/run1072_mwdc.parquet")
df.show(5)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/22 13:51:40 WARN Utils: Your hostname, gpuana02, resolves to a loopback address: 127.0.1.1; using 133.11.152.134 instead (on interface enp4s0)
# 26/01/22 13:51:40 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 26/01/22 13:51:40 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# +---------+-----------+----------+-----------+---------------+---------------+-----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+-----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------------+------------------+-------------------+-------------------+-------+
# |hbfNumber|sra_tdc_raw|dc31_x1_dl|dc31_x1_id0|dc31_x1_charge0|dc31_x1_timing0| dc31_x2_dl|dc31_x2_id0|dc31_x2_charge0|dc31_x2_timing0|dc31_y1_dl|dc31_y1_id0|dc31_y1_charge0|dc31_y1_timing0|dc31_y2_dl|dc31_y2_id0|dc31_y2_charge0|dc31_y2_timing0|dc31_x3_dl|dc31_x3_id0|dc31_x3_charge0|dc31_x3_timing0| dc31_x4_dl|dc31_x4_id0|dc31_x4_charge0|dc31_x4_timing0|dc31_y3_dl|dc31_y3_id0|dc31_y3_charge0|dc31_y3_timing0|dc31_y4_dl|dc31_y4_id0|dc31_y4_charge0|dc31_y4_timing0|dc32_x1_dl|dc32_x1_id0|dc32_x1_charge0|dc32_x1_timing0|dc32_x2_dl|dc32_x2_id0|dc32_x2_charge0|dc32_x2_timing0|dc32_y1_dl|dc32_y1_id0|dc32_y1_charge0|dc32_y1_timing0|dc32_y2_dl|dc32_y2_id0|dc32_y2_charge0|dc32_y2_timing0|dc31_x1_posi|dc31_x2_posi|dc31_x3_posi|dc31_x4_posi|dc31_y1_posi|dc31_y2_posi|dc31_y3_posi|dc31_y4_posi|dc32_x1_posi|dc32_x2_posi|dc32_y1_posi|dc32_y2_posi|            dc31_x|            dc31_y|             dc32_x|             dc32_y|runname|
# +---------+-----------+----------+-----------+---------------+---------------+-----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+-----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------------+------------------+-------------------+-------------------+-------+
# | 13737529|   43516784| 1.3270439|          8|       65.93179|     -22.914062|0.034205962|          8|       69.15508|     -43.160156| 1.0063053|          6|       69.15486|     -29.871094| 0.2826586|          6|      71.657524|     -42.570312|   1.43869|          8|       60.16129|       -20.4375|0.028901808|          8|       69.97312|     -43.984375|0.82198846|          6|       69.74925|     -33.359375|0.45132306|          6|      72.290405|     -41.007812| 1.1703353|          8|        77.8157|         -18.75|0.26853603|          8|       80.98976|     -33.339844| 1.3261197|          5|       75.26359|     -17.234375|0.13617265|          6|       80.70627|     -36.140625|   0.9229561|    0.854206|  0.86131006|   0.8689018|    4.756305|   4.8873415|   4.7719884|    4.848677|   1.0796647|    0.958536|   5.4238806|   5.3361726|0.8768434524536133| 4.816077709197998| 1.0191004276275635|  5.380026817321777|run1072|
# | 13555947|    1936448|  0.570068|          6|       71.49684|     -36.141357|  0.9903686|          7|       69.73142|     -29.435425|0.40693536|          9|       72.11514|     -39.823486| 1.1156851|         10|       69.62105|     -29.241333|0.49566025|          6|       70.63202|      -37.60266|  1.0811241|          7|      68.843506|     -28.547974|0.57637477|          9|       68.79171|      -37.25183| 0.9379437|         10|      68.531715|     -32.900513| 1.4650725|          7|      69.305115|     -12.682983|0.12658906|          7|       81.79154|      -34.48535| 1.3990943|         10|       71.69504|     -15.752319|0.07245436|         10|          78.11|       -36.6615|   -3.179932|  -3.1703687|  -3.2043397|  -3.2411242|   -5.656935|   -5.714315|   -5.626375|  -5.7620564|  -2.2150726|   -2.183411|  -6.8509054|  -6.8724546|-3.198941230773926|-5.689920425415039|-2.1992416381835938| -6.861680030822754|run1072|
# | 13354110|   12638718|  1.092771|          9|       70.75154|     -27.295898| 0.34196642|         10|       72.30578|     -40.115234| 1.2639159|          5|        66.6255|     -25.527344|0.09891538|          5|       72.46894|       -44.0459| 1.0756315|          9|        67.4321|     -28.006836| 0.37189406|         10|       70.81382|     -40.433594| 1.1061134|          5|      67.876495|     -28.558594|0.25751096|          5|      70.053406|     -43.381836| 1.1133382|         10|      77.793755|      -19.75293|0.36774737|         10|       78.13783|      -32.21582|0.84298456|          4|       74.13985|     -25.533203|  0.647498|          5|       79.74042|      -29.54004|    6.342771|    6.478033|    6.375632|   6.4681063|    8.013916|    8.071085|    8.056113|    8.042489|   7.1366615|   7.0577474|    8.907016|    8.847498| 6.416135787963867| 8.045900344848633|  7.097204208374023|  8.877256393432617|run1072|
# | 13593091|    5943448| 0.4568531|         10|       71.21283|     -37.651855|  1.0642089|         11|       67.13767|     -28.273438|0.75591356|         13|       67.50085|     -34.063477|  0.615111|         13|       70.30702|     -37.813477|0.44765043|         10|       71.33675|      -38.38867|  1.0936172|         11|        67.1838|     -28.311523|0.60380965|         13|      69.280106|      -36.86084|0.74504316|         13|      71.466835|     -36.254395|0.15055946|         11|      81.889984|     -34.063965|0.45586085|         12|     103.102905|     -30.744629| 0.8296325|         14|       75.42257|     -25.844238|0.68142533|         15|       83.80674|     -28.896973|    8.706853|    8.755791|    8.747651|    8.746383|  -16.494087|   -16.44511|   -16.44619|  -16.445044|   11.400559|   12.234139|  -21.079632|  -21.118576| 8.739169120788574|-16.45760726928711| 11.817349433898926|-21.099103927612305|run1072|
# | 13776362|    3759361| 1.3140085|         12|       70.06257|     -23.292725|   1.479926|         12|       71.82944|      -16.00122| 0.5776499|         11|      71.977356|      -37.16333| 1.4885674|          0|        73.8455|     -16.081787| 1.3175602|         12|       72.23422|     -23.512695|  0.7404502|          6|       69.67233|     -34.351807| 0.8706095|         11|      67.682335|     -32.616455| 1.4842113|          0|       76.31459|     -18.246826| 0.6439224|          4|       78.40869|      -27.78955| 0.7751572|          5|       82.15208|     -25.783936|  0.754691|         13|       75.73014|     -27.080078| 0.6978742|         13|       79.11751|     -28.689209|   15.564009|   14.299927|    15.61756|    -5.90045|   -11.82765|   24.658567|  -11.920609|    24.78421|   -9.106077|   -9.085156|   -16.49531|  -16.497875|  9.89526081085205|6.4236297607421875| -9.095617294311523|-16.496593475341797|run1072|
# +---------+-----------+----------+-----------+---------------+---------------+-----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+-----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+----------+-----------+---------------+---------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------------+------------------+-------------------+-------------------+-------+
# only showing top 5 rows

# %% [markdown]
# ## Plot x-y images for each plane

# %%
from matplotlib import pyplot as plt
from hist.sparkHist2d import Hist2D
from matplotlib.colors import LogNorm


planes = [(f"dc31_x{x}_posi", f"dc31_y{x}_posi") for x in range(1,5)]
planes = planes + [(f"dc32_x{x}_posi", f"dc32_y{x}_posi") for x in range(1,3)]
print(planes)
plt.figure(0, figsize=(12,12))
plt.rcParams["font.size"] = 8
for i, plane in enumerate(planes):
    q, mod = divmod(i,2)
    plt.subplot2grid((3,2),(q,mod))
    d = Hist2D(df, [plane[0],plane[1]],[500,500],[[-30,30],[-30,30]],  interpolation='none', norm=LogNorm())
plt.show()
# Out:
# [('dc31_x1_posi', 'dc31_y1_posi'), ('dc31_x2_posi', 'dc31_y2_posi'), ('dc31_x3_posi', 'dc31_y3_posi'), ('dc31_x4_posi', 'dc31_y4_posi'), ('dc32_x1_posi', 'dc32_y1_posi'), ('dc32_x2_posi', 'dc32_y2_posi')]
# Statistics:
# [[    0.     0.     0.]
#  [    0. 49069.     0.]
#  [    0.     0.     0.]]
# Statistics:
# [[    0.     0.     0.]
#  [    0. 49071.     0.]
#  [    0.     0.     0.]]
# Statistics:
# [[    0.     0.     0.]
#  [    0. 49084.     0.]
#  [    0.     0.     0.]]
# Statistics:
# [[    0.     0.     0.]
#  [    0. 49002.     0.]
#  [    0.     0.     0.]]
# Statistics:
# [[    0.     0.     0.]
#  [    0. 49059.     0.]
#  [    0.     0.     0.]]
# Statistics:
# [[    0.     0.     0.]
#  [    0. 49034.     0.]
#  [    0.     0.     0.]]

# %% [markdown]
# ## DC31 position resolution
# = errors on `dc31_x_posi` and `dc31_y_posi` in sigma

# %%
import math

from hist.sparkHist1d import Hist1D
planes = ["x", "y"]

n = df.count()
print(f"Number of events: {n}")
for plane in planes:
    dc31_planes = [f"dc31_{plane}{x}" for x in range(1,5)]

    df_avg = df.withColumn(f"dc31_{plane}_avg", sum(F.col(x+"_posi") for x in dc31_planes)/len(dc31_planes))
    stdevs = []
    plt.figure(0, figsize=(12,2))
    plt.rcParams["font.size"] = 4
    for i, pl in enumerate(dc31_planes):
        df_std = df_avg.withColumn(f"{pl}_diff", F.col(f"{pl}_posi") - F.col(f"dc31_{plane}_avg"))
        plt.subplot2grid((1,4),(0,i))
        h = Hist1D(df_std, f"{pl}_diff", 100, [-0.5, 0.5])
        df_std = df_std.filter(f"ABS({pl}_diff) < 0.8")
        df_std = df_std.withColumn(f"{pl}_resol", F.col(f"{pl}_diff")*F.col(f"{pl}_diff"))
        stdevs.append(df_std.select(F.sum(f"{pl}_resol")).collect()[0][0]/n)
    plt.show()
    print([math.sqrt(x) for x in stdevs])
    npl = float(len(stdevs))
    rms = math.sqrt(sum(stdevs)/npl*(npl-1))/npl
    print(f"DC31 {plane}-plane resolution: {rms*1000:.1f} um")
# Out:
# Number of events: 49333
# Total entries: 49664, Underflow: 830, Inside: 47604, Overflow: 1230
# Total entries: 49852, Underflow: 1018, Inside: 47817, Overflow: 1017
# Total entries: 49752, Underflow: 918, Inside: 47742, Overflow: 1092
# Total entries: 50025, Underflow: 1191, Inside: 47975, Overflow: 859
# [0.08402913324848665, 0.08157195900498253, 0.08730997302436093, 0.08376833577197558]
# DC31 x-plane resolution: 36.5 um
# Total entries: 49911, Underflow: 1020, Inside: 48313, Overflow: 578
# Total entries: 49449, Underflow: 558, Inside: 47912, Overflow: 979
# Total entries: 49809, Underflow: 918, Inside: 48263, Overflow: 628
# Total entries: 49516, Underflow: 625, Inside: 47941, Overflow: 950
# [0.08333832260701876, 0.07699413470518389, 0.08208873562012119, 0.08106308798379774]
# DC31 y-plane resolution: 35.0 um

# %% [markdown]
# ## DC32 Position Resolution
# = errors on `dc32_x_posi` and `dc32_y_posi` in sigma

# %%
planes = ["x", "y"]

n = df.count()
print(f"Number of events: {n}")
for plane in planes:
    dc32_planes = [f"dc32_{plane}{x}" for x in range(1,3)]

    df_avg = df.withColumn(f"dc32_{plane}_avg", sum(F.col(x+"_posi") for x in dc32_planes)/len(dc32_planes))
    stdevs = []
    plt.figure(0, figsize=(12,2))
    plt.rcParams["font.size"] = 4
    for i, pl in enumerate(dc32_planes):
        df_std = df_avg.withColumn(f"{pl}_diff", F.col(f"{pl}_posi") - F.col(f"dc32_{plane}_avg"))
        plt.subplot2grid((1,4),(0,i))
        h = Hist1D(df_std, f"{pl}_diff", 100, [-0.5, 0.5])
        df_std = df_std.filter(f"ABS({pl}_diff) < 0.8")
        df_std = df_std.withColumn(f"{pl}_resol", F.col(f"{pl}_diff")*F.col(f"{pl}_diff"))
        stdevs.append(df_std.select(F.sum(f"{pl}_resol")).collect()[0][0]/n)
    plt.show()
    print([math.sqrt(x) for x in stdevs])
    npl = len(stdevs)
    rms = math.sqrt(sum(stdevs)/npl*(npl-1))/npl
    print(f"DC32 {plane}-plane resolution: {rms*1000:.1f} um")
# Out:
# Number of events: 49333
# Total entries: 50275, Underflow: 1221, Inside: 48795, Overflow: 259
# Total entries: 49313, Underflow: 259, Inside: 47833, Overflow: 1221
# [0.07715721714833254, 0.07715721714833254]
# DC32 x-plane resolution: 38.6 um
# Total entries: 49485, Underflow: 450, Inside: 48828, Overflow: 207
# Total entries: 49242, Underflow: 207, Inside: 48585, Overflow: 450
# [0.08493700225742996, 0.08493700225742996]
# DC32 y-plane resolution: 42.5 um
